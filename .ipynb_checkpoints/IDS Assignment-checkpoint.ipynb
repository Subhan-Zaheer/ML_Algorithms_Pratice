# %%
import numpy as np
import pandas as pd
import os
import matplotlib as mpb
from matplotlib import pyplot as plt
import seaborn as sns

# %%
os.chdir("E:\subhan IDS\Data sets")

# %%
df = pd.read_csv("E:\subhan IDS\Data sets\Semester Project Dataset_1.csv")

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
region_wise_people_leaving_bank = df[df['IsActiveMember']==0]

# %%
region_wise_people_leaving_bank = region_wise_people_leaving_bank.groupby('Geography').count()

# %%
region_wise_people_leaving_bank
# Out:
#            CustomerId  Surname  CreditScore  Gender   Age  Tenure  Balance  \
# Geography
# France           2423     2423         2423    2423  2423    2423     2423
# Germany          1261     1261         1261    1261  1261    1261     1261
# Spain            1165     1165         1165    1165  1165    1165     1165
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# Geography
# France              2423       2423            2423             2423
# Germany             1261       1261            1261             1261
# Spain               1165       1165            1165             1165

# %%
labels = ['France', 'Germany', 'Spain']
explode = [0.05, 0.05, 0.05]

# %%
plt.pie(region_wise_people_leaving_bank['CustomerId'], labels= labels, explode= explode, autopct='%1.2f%%');

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
Salary = df['EstimatedSalary']

# %%
label = ['Salary in USD']
plt.boxplot(df['EstimatedSalary'], labels= label);

# %%
region = df['Geography'].value_counts()

# %%
region
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
my_labels = ['France', 'Germany', 'Spain']
plt.pie(region, autopct= '%1.2f%%', labels = my_labels);

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
NumOfProducts_by_Gender = df[['Gender', 'NumOfProducts']]

# %%
NumOfProducts_by_Gender1 = Salary_by_Gender.groupby('Gender').sum()

# %%
NumOfProducts_by_Gender
# Out:
#         NumOfProducts
# Gender
# Female           7015
# Male             8287

# %%
sns.displot(data= NumOfProducts_by_Gender, x= 'NumOfProducts', hue='Gender');

# %%
plt.hist(data = NumOfProducts_by_Gender,  x='Gender');

# %%
sns.barplot(data= df, x= 'Gender', y='NumOfProducts');

# %%
plt.bar(data = df, x = 'Gender', y = 'NumOfProducts')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12032\3684678771.py in <module>
# ----> 1 plt.bar(data = df, x = 'Gender', y = 'NumOfProducts')
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.plot(NumOfProducts_by_Gender1, '-o');
plt.title('Number of Products used by Male and Female');

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
new_df = df[df['IsActiveMember']==1]

# %%
new_df = new_df[['Geography', 'Gender', 'IsActiveMember']]

# %%
new_df
# Out:
#      Geography  Gender  IsActiveMember
# 0       France  Female               1
# 1        Spain  Female               1
# 4        Spain  Female               1
# 6       France    Male               1
# 8       France    Male               1
# ...        ...     ...             ...
# 9986   Germany    Male               1
# 9987     Spain    Male               1
# 9989     Spain    Male               1
# 9996    France    Male               1
# 9997    France  Female               1
#
# [5151 rows x 3 columns]

# %%
plt.figure(figsize=(20,15))

# %%
df1 = df.sample(1000)

sns.relplot(data = df1, x= 'EstimatedSalary', y='Age', hue='IsActiveMember');

# %%
df.sample(2000)
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 6534    15590078      Burns          622     Spain    Male   27       9
# 9425    15683977      Owens          687     Spain  Female   72       4
# 3696    15633586    Brierly          595    France  Female   39       7
# 4814    15615896  Chienezie          621     Spain    Male   39       8
# 3141    15769596        Yen          710   Germany  Female   24       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 5828    15684419    Wallace          709     Spain  Female   37       8
# 4162    15673584       Bell          652    France  Female   74       5
# 3951    15619972   Akabueze          807    France  Female   47       9
# 1483    15790683   Matthews          850    France    Male   36       1
# 5249    15804038      Quinn          740    France    Male   44       9
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data = df, x= 'Geography', y= 'Tenure', hue='Gender');

# %%
sns.catplot(data = df.sample(3000), kind='swarm', x= 'Geography', y= 'Tenure', hue='Gender');
# Out:
# E:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# E:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 76.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# E:\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
df1 = df.sample(1000)
plt.figure(figsize=(18,8))
sns.lineplot(df1['Tenure'], df1['EstimatedSalary'], marker='*')
sns.lineplot(df1['Tenure'], df1['Balance'], marker='d')
plt.legend(labels=[
                   'EstimateSalary',
                   'Balance'
])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lineplot(df1['Tenure'], df1['Age'], marker='o')
plt.figure(figsize=(8,0), dpi=100)
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df.sample(500), hue='Gender')
